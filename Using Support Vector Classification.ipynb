# %%
import pandas as pd
import re
from sklearn import svm
REMOVECHAR = ['।' , '?' , '#' , ',' , '!' , ':' , '.' , '”']

# %%
sms=pd.read_csv("msgs.csv",encoding='utf-8')
sms=sms.rename(columns = {'c1':'label','c2':'message'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a84c827b1029> in <module>()
# ----> 1 sms=pd.read_csv("ratings.csv",encoding='utf-8')
#       2 sms=sms.rename(columns = {'c1':'label','c2':'message'})
#
# NameError: name 'pd' is not defined

# %%
sms.head(20)
# sms['message'].replace
# Out:
#    label                                            message
# 0   spam  बिभिन्न किसिमका सेक्स टोयहरु उपलबध छ। सम्पर्क ...
# 1    ham   कृपया तिम्रो डकुमेनट अहिले पठाउ यदि समभव छ भने ।
# 2   spam       ३जी सेवा लिदा एक महिनाका लागि नेट सेवा फ्रि।
# 3    ham                      म लोक सेवा आयोग गइरहेको छु ।
# 4    ham                        घर पुगेपछि मलाई फोन गरनुस ।
# 5    ham             छठ र्पव के अवसर पर बहुत बहुत शुभकमना ।
# 6    ham  भोलि म उपत्यका बाहिर जादैछु उता बाट फरके पछि क...
# 7   spam  अर्जेन्ट अवश्कता मल्टिनेशसनल कम्पनिका लागि १० ...
# 8   spam  लिङगको लम्बाईमोटाईउतेजना बढाउन शिघ्रपतन हटाउन ...
# 9    ham                     नमस्कारदाङ्गतिरको हालखबर के छ।
# 10  spam  *५७६*६७# मा डाएल गर्नुस र सुरेलि अँखियो वालि ग...
# 11  spam              नयाँ बर्षको विशेष छुटकौल 5240562 मा ।
# 12   ham                        अभि के म आज र्कितीपुर आउँ ।
# 13   ham                                 सर आज क्लास हुदैन।
# 14  spam  टोल फ्री नम्बर १२३ मा कौल गरी ३ रूपैयामा दैनिक...
# 15   ham  आज तिमीले कौल गरेको होक्लास त्यति छैन। त्यसैल ...
# 16   ham           बधाई छ तपाईलाई थेसिस कमपलिट गरनुभएकोमा ।
# 17   ham  हाम्रो घरतिर पानि घुमन आउदा हुन्छ निभाउजुलाई स...
# 18   ham                            मेरो काम भए कि भएन सर ।
# 19   ham                      नमस्ते सर जीसन्चै हुनुहुन्छ ।

# %%
X_train=sms["message"][:120]
Y_train=sms["label"][:120]
X_test=sms["message"][121:178]
Y_test=sms["label"][121:178]

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
vectorizer=CountVectorizer(analyzer = "word",tokenizer = None,preprocessor = None,stop_words = None,max_features = 5000)

# %%
train_data_features=vectorizer.fit_transform(X_train)
train_data_features=train_data_features.toarray()

test_data_features=vectorizer.transform(X_test)
test_data_features=test_data_features.toarray()

#SVM with linear kernel
clf=svm.SVC(kernel='linear',C=1.0)
print ("Training")
clf.fit(train_data_features,Y_train)
# Out:
# Training
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
print ("Testing")
predicted=clf.predict(test_data_features)
accuracy=np.mean(predicted==Y_test)
print ("Accuracy: ",accuracy)

#Validation
X=sms["message"]
validation_data=vectorizer.transform(X)
validation_data=validation_data.toarray()
# Out:
# Testing
# Accuracy:  0.785714285714

# %%
classification=clf.predict(validation_data)
for i in range(0,len(sms.message)):
    print(sms.message[i], classification[i])
# Out:
# बिभिन्न किसिमका सेक्स टोयहरु उपलबध छ। सम्पर्क गर्ने ठेगना तल उल्लेख गरिएको छ। spam
